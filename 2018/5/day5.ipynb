# %%
# PART 1

# read file
file = open("input.txt","r")

# check file mode and readlines
if file.mode == 'r':
    data = file.read().splitlines()[0]

data = list(data)
# loop through string
i = 1
while i < len(data):
    # check for duplicate letters, but different type
    if(data[i-1].capitalize() == data[i].capitalize() and data[i-1] != data[i]):
        # remove letters
        data.pop(i-1)
        data.pop(i-1)
        # reset i
        i -= 1
    else:
        i += 1
len(data)
# Out:
# 11946

# %%
# PART 2
import string
# read file
file = open("input.txt","r")

# check file mode and readlines
if file.mode == 'r':
    data = file.read().splitlines()[0]

original_data = list(data)
letters = list(string.ascii_lowercase[:26])
minimum = len(data)
# loop through string
for l in letters:
    data_new = original_data.copy()
    h = 1
    while h < len(data_new):
        if(data_new[h].capitalize() == l.capitalize()):
            data_new.pop(h)
        else:
            h += 1 
    i = 1
    while i < len(data_new):
        # check for duplicate letters, but different type
        if(data_new[i-1].capitalize() == data_new[i].capitalize() and data_new[i-1] != data[i]):
            # remove letters
            data_new.pop(i-1)
            data_new.pop(i-1)
            # reset i
            i -= 2
        else:
            i +=1
    if minimum > len(data_new):
        minimum = len(data_new)
    print(l)
    print(len(data_new))
# Out:
# a
# 12236
# b
# 12188
# c
# 12334
# d
# 12116
# e
# 12100
# f
# 12314
# g
# 12102
# h
# 12004
# i
# 12248
# j
# 12048
# k
# 12126
# l
# 12182
# m
# 12182
# n
# 12268
# o
# 12052
# p
# 12058
# q
# 12250
# r
# 12250
# s
# 12096
# t
# 12306
# u
# 12083
# v
# 12256
# w
# 12086
# x
# 12116
# y
# 12188
# z
# 12384

# %%
data_new
# Out:
# ['s',
#  'q',
#  'v',
#  'V',
#  'q',
#  'W',
#  'K',
#  'k',
#  'w',
#  'k',
#  'j',
#  'o',
#  'O',
#  'j',
#  's',
#  'x',
#  'X',
#  'S',
#  'K',
#  'N',
#  'w',
#  'J',
#  'j',
#  'W',
#  'V',
#  'b',
#  'G',
#  'u',
#  'Q',
#  'h',
#  'd',
#  'T',
#  't',
#  'h',
#  'u',
#  'U',
#  'c',
#  'v',
#  'V',
#  'u',
#  'B',
#  'Y',
#  'K',
#  'T',
#  'u',
#  'U',
#  'M',
#  'e',
#  'J',
#  'j',
#  'e',
#  'm',
#  'R',
#  'u',
#  's',
#  'S',
#  'Y',
#  'J',
#  'H',
#  'F',
#  'l',
#  'F',
#  'g',
#  'o',
#  'K',
#  'm',
#  'h',
#  'U',
#  'i',
#  'B',
#  'L',
#  'U',
#  'n',
#  'T',
#  'K',
#  'j',
#  'e',
#  'd',
#  'v',
#  'O',
#  'o',
#  'K',
#  'C',
#  'M',
#  't',
#  'r',
#  'R',
#  'o',
#  'u',
#  'O',
#  'g',
#  'O',
#  'o',
#  'G',
#  'O',
#  'o',
#  'U',
#  'E',
#  's',
#  'h',
#  'C',
#  'L',
#  'e',
#  'E',
#  'l',
#  'c',
#  'p',
#  'y',
#  'Y',
#  'P',
#  'J',
#  'x',
#  'h',
#  'H',
#  'h',
#  'r',
#  'G',
#  'w',
#  'W',
#  'g',
#  'w',
#  'I',
#  'm',
#  'M',
#  'i',
#  'B',
#  'v',
#  'k',
#  'u',
#  'Y',
#  'W',
#  'w',
#  'y',
#  'U',
#  'S',
#  'b',
#  'B',
#  's',
#  'Y',
#  'E',
#  'G',
#  'u',
#  'S',
#  'Q',
#  'u',
#  'A',
#  'v',
#  'W',
#  'c',
#  'O',
#  'M',
#  'i',
#  'D',
#  'f',
#  'H',
#  'b',
#  'B',
#  'o',
#  'd',
#  'S',
#  'c',
#  'q',
#  'f',
#  'Y',
#  'W',
#  'X',
#  'A',
#  'L',
#  'x',
#  'F',
#  'f',
#  'X',
#  'C',
#  'l',
#  'S',
#  'W',
#  'v',
#  'J',
#  'T',
#  'i',
#  'b',
#  'A',
#  'R',
#  'r',
#  'a',
#  'b',
#  'I',
#  'f',
#  'f',
#  'g',
#  'J',
#  'j',
#  'l',
#  'n',
#  'L',
#  'K',
#  'G',
#  'q',
#  'j',
#  'o',
#  'O',
#  's',
#  'S',
#  'o',
#  's',
#  'o',
#  'e',
#  't',
#  'X',
#  'y',
#  'a',
#  'k',
#  's',
#  'u',
#  'U',
#  'B',
#  'j',
#  'J',
#  'B',
#  'd',
#  'k',
#  'j',
#  'h',
#  'o',
#  'm',
#  'G',
#  'p',
#  'D',
#  'P',
#  'A',
#  'N',
#  'I',
#  'u',
#  'a',
#  'm',
#  'B',
#  'D',
#  'b',
#  'L',
#  's',
#  'q',
#  'J',
#  'u',
#  'F',
#  'f',
#  'U',
#  'j',
#  'Q',
#  'S',
#  'y',
#  'F',
#  'h',
#  'y',
#  'x',
#  'F',
#  'e',
#  'G',
#  'q',
#  'R',
#  'e',
#  'E',
#  'n',
#  'D',
#  'v',
#  'V',
#  'd',
#  'K',
#  'g',
#  'U',
#  'S',
#  'K',
#  'V',
#  'O',
#  's',
#  'K',
#  'p',
#  'A',
#  'c',
#  'V',
#  'w',
#  'W',
#  'I',
#  'R',
#  'N',
#  'Y',
#  'F',
#  'C',
#  'E',
#  'o',
#  'x',
#  'I',
#  'f',
#  's',
#  'S',
#  'm',
#  'k',
#  's',
#  'd',
#  'S',
#  'W',
#  'w',
#  'i',
#  'F',
#  'b',
#  'r',
#  'j',
#  'R',
#  'y',
#  'A',
#  'E',
#  'e',
#  'U',
#  'E',
#  't',
#  'E',
#  'x',
#  'D',
#  'i',
#  'T',
#  'S',
#  'p',
#  'v',
#  'B',
#  'F',
#  's',
#  'R',
#  'r',
#  'i',
#  'y',
#  'm',
#  'N',
#  'L',
#  'p',
#  'x',
#  'v',
#  'm',
#  'b',
#  'Q',
#  'q',
#  'e',
#  'x',
#  'M',
#  'w',
#  'f',
#  'x',
#  'E',
#  'k',
#  'm',
#  'f',
#  'N',
#  'h',
#  'L',
#  'r',
#  'd',
#  'h',
#  'r',
#  'h',
#  'W',
#  't',
#  'R',
#  'O',
#  'S',
#  'n',
#  'N',
#  'P',
#  'T',
#  'U',
#  'j',
#  'T',
#  'L',
#  'v',
#  'W',
#  'm',
#  'F',
#  'f',
#  'T',
#  'O',
#  'j',
#  'O',
#  'K',
#  'N',
#  'G',
#  'R',
#  'c',
#  'C',
#  'r',
#  'g',
#  'P',
#  'g',
#  'G',
#  'I',
#  'X',
#  'o',
#  'S',
#  'W',
#  'w',
#  's',
#  'q',
#  'r',
#  'd',
#  'b',
#  'Q',
#  's',
#  'L',
#  'G',
#  'j',
#  'K',
#  'k',
#  'f',
#  'b',
#  'B',
#  'c',
#  'S',
#  'j',
#  'Q',
#  'X',
#  'x',
#  'p',
#  'H',
#  'p',
#  'T',
#  'O',
#  't',
#  's',
#  'e',
#  't',
#  'r',
#  'n',
#  'B',
#  'A',
#  'a',
#  'b',
#  'N',
#  'R',
#  'T',
#  'S',
#  'K',
#  'M',
#  'C',
#  's',
#  'e',
#  'd',
#  'k',
#  'd',
#  'F',
#  'O',
#  'K',
#  'Y',
#  'n',
#  'L',
#  'X',
#  'a',
#  'F',
#  'H',
#  'B',
#  'a',
#  'y',
#  'M',
#  'T',
#  'B',
#  'v',
#  's',
#  'l',
#  'F',
#  'q',
#  'd',
#  'p',
#  'G',
#  'I',
#  'M',
#  'm',
#  'U',
#  'F',
#  'q',
#  'P',
#  'G',
#  'H',
#  'h',
#  'O',
#  'x',
#  'Q',
#  'k',
#  'H',
#  'b',
#  'B',
#  'h',
#  'Y',
#  'v',
#  'D',
#  'E',
#  'U',
#  'L',
#  'J',
#  'j',
#  'l',
#  'U',
#  'P',
#  'I',
#  'b',
#  'B',
#  'p',
#  'B',
#  'l',
#  'd',
#  'i',
#  'm',
#  'X',
#  'g',
#  'a',
#  'L',
#  'T',
#  'w',
#  'I',
#  'T',
#  'E',
#  'x',
#  'm',
#  'r',
#  'l',
#  'D',
#  'C',
#  'y',
#  'C',
#  'M',
#  'l',
#  'Y',
#  'P',
#  'e',
#  'w',
#  'I',
#  'b',
#  'u',
#  'E',
#  'M',
#  'm',
#  'u',
#  'p',
#  'J',
#  's',
#  'U',
#  'g',
#  'y',
#  'e',
#  'D',
#  'M',
#  'S',
#  'm',
#  'R',
#  'c',
#  'C',
#  'r',
#  'B',
#  'b',
#  'P',
#  'x',
#  'V',
#  'e',
#  'i',
#  'g',
#  'F',
#  'S',
#  'w',
#  'i',
#  'X',
#  'I',
#  'u',
#  'R',
#  'n',
#  'Y',
#  'W',
#  'b',
#  'g',
#  'K',
#  'q',
#  'O',
#  'P',
#  'x',
#  'B',
#  'W',
#  'f',
#  'r',
#  'D',
#  'H',
#  'Y',
#  'k',
#  's',
#  'c',
#  'l',
#  'E',
#  'Y',
#  'B',
#  'I',
#  'q',
#  'O',
#  'v',
#  'H',
#  'N',
#  'g',
#  'Y',
#  'J',
#  'a',
#  'T',
#  'O',
#  'Y',
#  'G',
#  'R',
#  'M',
#  't',
#  'T',
#  'm',
#  'f',
#  'c',
#  'L',
#  'l',
#  'E',
#  'n',
#  'O',
#  'f',
#  'H',
#  'w',
#  'u',
#  'W',
#  'H',
#  'g',
#  'C',
#  'Q',
#  'H',
#  'b',
#  'K',
#  'b',
#  'I',
#  'I',
#  'E',
#  'u',
#  't',
#  'd',
#  'q',
#  'Q',
#  'd',
#  'A',
#  'P',
#  'F',
#  'C',
#  'c',
#  'd',
#  'N',
#  'C',
#  'x',
#  'R',
#  'c',
#  'S',
#  'A',
#  'c',
#  'B',
#  's',
#  'W',
#  'l',
#  'F',
#  't',
#  'c',
#  'S',
#  'L',
#  'r',
#  'w',
#  'u',
#  'M',
#  'A',
#  'g',
#  'd',
#  'L',
#  'u',
#  'U',
#  'l',
#  'H',
#  'm',
#  'F',
#  'f',
#  'M',
#  'K',
#  'g',
#  'I',
#  'c',
#  'x',
#  'R',
#  'a',
#  'y',
#  'g',
#  'W',
#  'E',
#  'P',
#  'G',
#  'o',
#  't',
#  'i',
#  'J',
#  'E',
#  'J',
#  'Q',
#  't',
#  'K',
#  'H',
#  'i',
#  'v',
#  'u',
#  'h',
#  'G',
#  'd',
#  'D',
#  'a',
#  'n',
#  'M',
#  'N',
#  'O',
#  'n',
#  'X',
#  'I',
#  'b',
#  'w',
#  'u',
#  'j',
#  'H',
#  'G',
#  'n',
#  'x',
#  'D',
#  'x',
#  'v',
#  'V',
#  'X',
#  'A',
#  'g',
#  'w',
#  'e',
#  'j',
#  'N',
#  'X',
#  'y',
#  'L',
#  'C',
#  'p',
#  'l',
#  'b',
#  'u',
#  'E',
#  'w',
#  'V',
#  'r',
#  'y',
#  'R',
#  'e',
#  'n',
#  't',
#  'V',
#  'P',
#  'k',
#  'n',
#  't',
#  'M',
#  'P',
#  'l',
#  'b',
#  'v',
#  'D',
#  'U',
#  'm',
#  'T',
#  'G',
#  'x',
#  'n',
#  'M',
#  'a',
#  'L',
#  'H',
#  'g',
#  'x',
#  'c',
#  'I',
#  'i',
#  'C',
#  'F',
#  'R',
#  'B',
#  'x',
#  'O',
#  'w',
#  'p',
#  'K',
#  'A',
#  'r',
#  'U',
#  'q',
#  'j',
#  'i',
#  'N',
#  'G',
#  'g',
#  'G',
#  'p',
#  'Y',
#  'i',
#  'G',
#  'x',
#  'o',
#  'r',
#  'C',
#  'd',
#  't',
#  'o',
#  'F',
#  'k',
#  'J',
#  'j',
#  'K',
#  'm',
#  'c',
#  'n',
#  'v',
#  'I',
#  'N',
#  'n',
#  'i',
#  'p',
#  'I',
#  'j',
#  'h',
#  'm',
#  'G',
#  'r',
#  'O',
#  'S',
#  'A',
#  'P',
#  'h',
#  'G',
#  'A',
#  'f',
#  'F',
#  'W',
#  'q',
#  'U',
#  'w',
#  'X',
#  'y',
#  'n',
#  'o',
#  'A',
#  'V',
#  'c',
#  'X',
#  'T',
#  'H',
#  'U',
#  'R',
#  'O',
#  'R',
#  'S',
#  'N',
#  'H',
#  'h',
#  'O',
#  'X',
#  'x',
#  'g',
#  'W',
#  'N',
#  'j',
#  'W',
#  'O',
#  'f',
#  'b',
#  'o',
#  'l',
#  'm',
#  'W',
#  'e',
#  'a',
#  'g',
#  'x',
#  'X',
#  'G',
#  'Q',
#  'T',
#  'c',
#  'M',
#  'k',
#  'w',
#  's',
#  'G',
#  'o',
#  'B',
#  'o',
#  'G',
#  'O',
#  'p',
#  'B',
#  'B',
#  'P',
#  'A',
#  'v',
#  'G',
#  'w',
#  'W',
#  'e',
#  'p',
#  'f',
#  'M',
#  'K',
#  'd',
#  'C',
#  'B',
#  'k',
#  'M',
#  'd',
#  'G',
#  'H',
#  'm',
#  'S',
#  'e',
#  'g',
#  'f',
#  'U',
#  'H',
#  'e',
#  'p',
#  'w',
#  'O',
#  'B',
#  'c',
#  'R',
#  'K',
#  'n',
#  'H',
#  'R',
#  'c',
#  'c',
#  'r',
#  'i',
#  'l',
#  'C',
#  'e',
#  'F',
#  'e',
#  'm',
#  'b',
#  'I',
#  'x',
#  'D',
#  'r',
#  'x',
#  'S',
#  'J',
#  'v',
#  'j',
#  'U',
#  'B',
#  'I',
#  'l',
#  'i',
#  'd',
#  'B',
#  'E',
#  'c',
#  'C',
#  'e',
#  'T',
#  'u',
#  'X',
#  'H',
#  'l',
#  'K',
#  'a',
#  'o',
#  'r',
#  'a',
#  'w',
#  'I',
#  'K',
#  'q',
#  'v',
#  'C',
#  'x',
#  'X',
#  'c',
#  'o',
#  'k',
#  'O',
#  'f',
#  'd',
#  'q',
#  'f',
#  'u',
#  'N',
#  'e',
#  'k',
#  'F',
#  'q',
#  'd',
#  'W',
#  'o',
#  'm',
#  ...]

# %%
count_letters = Counter(data_new)

# %%
count_letters
# Out:
# Counter({'s': 259,
#          'q': 244,
#          'v': 244,
#          'V': 256,
#          'W': 279,
#          'K': 249,
#          'k': 251,
#          'w': 283,
#          'j': 237,
#          'o': 267,
#          'O': 263,
#          'x': 252,
#          'X': 242,
#          'S': 256,
#          'N': 248,
#          'J': 231,
#          'b': 250,
#          'G': 275,
#          'u': 258,
#          'Q': 243,
#          'h': 264,
#          'd': 262,
#          'T': 237,
#          't': 235,
#          'U': 258,
#          'c': 245,
#          'B': 252,
#          'Y': 236,
#          'M': 245,
#          'e': 249,
#          'm': 251,
#          'R': 222,
#          'H': 256,
#          'F': 231,
#          'l': 232,
#          'g': 265,
#          'i': 245,
#          'L': 234,
#          'n': 256,
#          'C': 235,
#          'r': 230,
#          'E': 239,
#          'p': 244,
#          'y': 236,
#          'P': 242,
#          'I': 249,
#          'A': 230,
#          'D': 258,
#          'f': 237,
#          'a': 220})
