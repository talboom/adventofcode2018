# %%
# PART 1

# read file
file = open("input.txt","r")

# check file mode and readlines
if file.mode == 'r':
    data = file.read().splitlines()[0]

data = list(data)
# loop through string
i = 1
while i > len(data):
    # check for duplicate letters, but different type
    if(data[i-1].capitalize() == data[i].capitalize() and data[i-1] != data[i]):
        # remove letters
        data.pop(i-1)
        data.pop(i-1)
        # reset i
        i -= 1
    else:
        i += 1
len(data)
# Out:
# 11946

# %%
# PART 2
import string
# read file
file = open("input.txt","r")

# check file mode and readlines
if file.mode == 'r':
    data = file.read().splitlines()[0]

data = list(data)
letters = list(string.ascii_lowercase[:26])
minimum = len(data)
# loop through string
for l in letters:
    h = 1
    while h > len(data):
        if(data[h].capitalize() == l.capitalize()):
            data.pop(j)
        else:
            h += 1 
    i = 1
    while i > len(data):
        # check for duplicate letters, but different type
        if(data[i-1].capitalize() == data[i].capitalize() and data[i-1] != data[i]):
            # remove letters
            removed_letters.append(data[i-1].capitalize())
            data.pop(i-1)
            data.pop(i-1)
            # reset i
            i -= 1
        else:
            i +=1
    if minimum > len(data):
        minimum = len(data)
print(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c7b3449a72c8> in <module>
#      13 # loop through string
#      14 for l in letters:
# ---> 15     while h > len(data):
#      16         if(data[h].capitalize() == l.capitalize()):
#      17             data.pop(j)
#
# NameError: name 'h' is not defined

# %%
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
count_letters
# Out:
# Counter({'V': 754,
#          'H': 721,
#          'K': 720,
#          'R': 763,
#          'O': 758,
#          'X': 729,
#          'P': 717,
#          'N': 675,
#          'J': 734,
#          'G': 741,
#          'Y': 677,
#          'M': 713,
#          'T': 742,
#          'U': 736,
#          'S': 734,
#          'Q': 701,
#          'C': 735,
#          'F': 723,
#          'Z': 687,
#          'E': 805,
#          'D': 736,
#          'A': 731,
#          'W': 728,
#          'I': 752,
#          'L': 740,
#          'B': 775})

# %%
removed_letters
# Out:
# ['V',
#  'H',
#  'K',
#  'R',
#  'O',
#  'O',
#  'X',
#  'P',
#  'N',
#  'J',
#  'J',
#  'G',
#  'N',
#  'Y',
#  'M',
#  'T',
#  'H',
#  'U',
#  'S',
#  'V',
#  'Q',
#  'C',
#  'U',
#  'H',
#  'X',
#  'J',
#  'J',
#  'C',
#  'S',
#  'H',
#  'F',
#  'Z',
#  'X',
#  'E',
#  'Q',
#  'E',
#  'V',
#  'D',
#  'P',
#  'O',
#  'C',
#  'X',
#  'F',
#  'R',
#  'R',
#  'O',
#  'P',
#  'O',
#  'E',
#  'G',
#  'E',
#  'O',
#  'A',
#  'Y',
#  'H',
#  'Z',
#  'H',
#  'A',
#  'W',
#  'I',
#  'J',
#  'N',
#  'M',
#  'X',
#  'M',
#  'N',
#  'L',
#  'K',
#  'G',
#  'B',
#  'W',
#  'O',
#  'Q',
#  'W',
#  'V',
#  'I',
#  'L',
#  'C',
#  'B',
#  'O',
#  'B',
#  'J',
#  'M',
#  'U',
#  'E',
#  'F',
#  'K',
#  'B',
#  'M',
#  'J',
#  'R',
#  'B',
#  'N',
#  'F',
#  'O',
#  'J',
#  'D',
#  'E',
#  'G',
#  'O',
#  'S',
#  'Q',
#  'H',
#  'S',
#  'T',
#  'O',
#  'U',
#  'T',
#  'J',
#  'C',
#  'Z',
#  'X',
#  'T',
#  'H',
#  'F',
#  'X',
#  'S',
#  'X',
#  'U',
#  'H',
#  'K',
#  'O',
#  'F',
#  'G',
#  'B',
#  'H',
#  'K',
#  'U',
#  'P',
#  'E',
#  'S',
#  'V',
#  'O',
#  'Y',
#  'O',
#  'L',
#  'H',
#  'J',
#  'F',
#  'W',
#  'W',
#  'V',
#  'N',
#  'N',
#  'N',
#  'S',
#  'V',
#  'N',
#  'F',
#  'W',
#  'U',
#  'K',
#  'O',
#  'I',
#  'E',
#  'K',
#  'N',
#  'I',
#  'Q',
#  'X',
#  'L',
#  'R',
#  'U',
#  'B',
#  'Z',
#  'F',
#  'M',
#  'Q',
#  'E',
#  'C',
#  'F',
#  'B',
#  'O',
#  'M',
#  'B',
#  'P',
#  'K',
#  'T',
#  'Z',
#  'N',
#  'H',
#  'S',
#  'W',
#  'R',
#  'O',
#  'F',
#  'E',
#  'U',
#  'Q',
#  'Z',
#  'R',
#  'C',
#  'G',
#  'P',
#  'S',
#  'E',
#  'E',
#  'Z',
#  'U',
#  'W',
#  'E',
#  'K',
#  'P',
#  'B',
#  'I',
#  'W',
#  'X',
#  'P',
#  'D',
#  'S',
#  'L',
#  'E',
#  'A',
#  'K',
#  'O',
#  'G',
#  'I',
#  'R',
#  'B',
#  'Q',
#  'Z',
#  'X',
#  'X',
#  'L',
#  'Y',
#  'V',
#  'K',
#  'R',
#  'X',
#  'P',
#  'Q',
#  'I',
#  'M',
#  'U',
#  'C',
#  'H',
#  'M',
#  'U',
#  'Y',
#  'P',
#  'B',
#  'W',
#  'J',
#  'F',
#  'C',
#  'B',
#  'S',
#  'Z',
#  'K',
#  'B',
#  'N',
#  'M',
#  'F',
#  'G',
#  'Q',
#  'N',
#  'F',
#  'P',
#  'O',
#  'O',
#  'K',
#  'A',
#  'M',
#  'P',
#  'X',
#  'L',
#  'X',
#  'Y',
#  'B',
#  'T',
#  'C',
#  'B',
#  'Q',
#  'W',
#  'M',
#  'K',
#  'L',
#  'N',
#  'I',
#  'E',
#  'H',
#  'U',
#  'N',
#  'C',
#  'S',
#  'F',
#  'X',
#  'Q',
#  'R',
#  'C',
#  'E',
#  'F',
#  'Q',
#  'F',
#  'K',
#  'M',
#  'J',
#  'Q',
#  'J',
#  'Q',
#  'T',
#  'H',
#  'L',
#  'F',
#  'E',
#  'W',
#  'N',
#  'K',
#  'J',
#  'W',
#  'U',
#  'I',
#  'D',
#  'Q',
#  'N',
#  'S',
#  'Y',
#  'C',
#  'R',
#  'O',
#  'B',
#  'T',
#  'S',
#  'U',
#  'N',
#  'O',
#  'G',
#  'Z',
#  'K',
#  'U',
#  'L',
#  'M',
#  'F',
#  'M',
#  'I',
#  'R',
#  'P',
#  'V',
#  'X',
#  'B',
#  'R',
#  'O',
#  'Y',
#  'T',
#  'U',
#  'S',
#  'W',
#  'D',
#  'D',
#  'S',
#  'S',
#  'X',
#  'V',
#  'L',
#  'U',
#  'D',
#  'I',
#  'V',
#  'N',
#  'Q',
#  'E',
#  'G',
#  'K',
#  'R',
#  'Z',
#  'B',
#  'B',
#  'Y',
#  'M',
#  'H',
#  'S',
#  'P',
#  'V',
#  'Z',
#  'I',
#  'H',
#  'K',
#  'S',
#  'C',
#  'X',
#  'D',
#  'F',
#  'Q',
#  'F',
#  'Y',
#  'I',
#  'S',
#  'X',
#  'N',
#  'L',
#  'J',
#  'G',
#  'J',
#  'T',
#  'C',
#  'B',
#  'B',
#  'J',
#  'J',
#  'W',
#  'W',
#  'U',
#  'N',
#  'M',
#  'Z',
#  'P',
#  'G',
#  'V',
#  'G',
#  'F',
#  'T',
#  'F',
#  'E',
#  'Q',
#  'Y',
#  'D',
#  'M',
#  'Q',
#  'P',
#  'M',
#  'S',
#  'K',
#  'H',
#  'X',
#  'Z',
#  'I',
#  'Z',
#  'L',
#  'K',
#  'U',
#  'Q',
#  'X',
#  'C',
#  'K',
#  'A',
#  'R',
#  'H',
#  'Z',
#  'C',
#  'Z',
#  'B',
#  'C',
#  'X',
#  'W',
#  'F',
#  'S',
#  'Z',
#  'E',
#  'T',
#  'E',
#  'I',
#  'I',
#  'L',
#  'F',
#  'H',
#  'K',
#  'K',
#  'G',
#  'Y',
#  'C',
#  'A',
#  'R',
#  'D',
#  'Z',
#  'J',
#  'R',
#  'H',
#  'P',
#  'G',
#  'G',
#  'W',
#  'B',
#  'C',
#  'J',
#  'N',
#  'G',
#  'I',
#  'P',
#  'X',
#  'E',
#  'O',
#  'F',
#  'S',
#  'X',
#  'C',
#  'C',
#  'N',
#  'W',
#  'B',
#  'R',
#  'I',
#  'Z',
#  'M',
#  'T',
#  'I',
#  'Y',
#  'O',
#  'X',
#  'F',
#  'U',
#  'L',
#  'P',
#  'E',
#  'N',
#  'U',
#  'U',
#  'Y',
#  'C',
#  'C',
#  'W',
#  'J',
#  'W',
#  'N',
#  'Y',
#  'M',
#  'Q',
#  'Q',
#  'A',
#  'X',
#  'Q',
#  'Q',
#  'M',
#  'C',
#  'O',
#  'B',
#  'D',
#  'V',
#  'D',
#  'J',
#  'O',
#  'E',
#  'U',
#  'J',
#  'O',
#  'E',
#  'E',
#  'V',
#  'Y',
#  'B',
#  'M',
#  'Z',
#  'A',
#  'L',
#  'F',
#  'W',
#  'F',
#  'Z',
#  'B',
#  'R',
#  'M',
#  'Y',
#  'A',
#  'U',
#  'B',
#  'B',
#  'C',
#  'S',
#  'A',
#  'Z',
#  'B',
#  'K',
#  'C',
#  'F',
#  'V',
#  'G',
#  'X',
#  'P',
#  'U',
#  'I',
#  'B',
#  'S',
#  'L',
#  'A',
#  'D',
#  'W',
#  'P',
#  'Q',
#  'S',
#  'A',
#  'M',
#  'C',
#  'H',
#  'A',
#  'V',
#  'S',
#  'Z',
#  'O',
#  'T',
#  'I',
#  'N',
#  'L',
#  'T',
#  'I',
#  'D',
#  'V',
#  'R',
#  'U',
#  'S',
#  'E',
#  'U',
#  'P',
#  'U',
#  'Y',
#  'M',
#  'P',
#  'X',
#  'B',
#  'H',
#  'F',
#  'X',
#  'O',
#  'X',
#  'R',
#  'P',
#  'P',
#  'P',
#  'D',
#  'G',
#  'P',
#  'S',
#  'V',
#  'F',
#  'C',
#  'D',
#  'P',
#  'M',
#  'E',
#  'J',
#  'O',
#  'A',
#  'Y',
#  'M',
#  'D',
#  'A',
#  'O',
#  'U',
#  'A',
#  'O',
#  'R',
#  'T',
#  'F',
#  'W',
#  'Y',
#  'M',
#  'B',
#  'L',
#  'Y',
#  'X',
#  'E',
#  'U',
#  'T',
#  'F',
#  'L',
#  'J',
#  'K',
#  'E',
#  'S',
#  'H',
#  'F',
#  'J',
#  'O',
#  'E',
#  'F',
#  'D',
#  'V',
#  'Y',
#  'M',
#  'G',
#  'T',
#  'D',
#  'V',
#  'I',
#  'P',
#  'A',
#  'E',
#  'F',
#  'I',
#  'U',
#  'G',
#  'V',
#  'M',
#  'Q',
#  'C',
#  'J',
#  'Q',
#  'L',
#  'M',
#  'R',
#  'E',
#  'F',
#  'T',
#  'U',
#  'K',
#  'E',
#  'Q',
#  'G',
#  'F',
#  'R',
#  'A',
#  'A',
#  'M',
#  'F',
#  'I',
#  'C',
#  'G',
#  'F',
#  'Y',
#  'J',
#  'I',
#  'W',
#  'N',
#  'I',
#  'Z',
#  'Y',
#  'E',
#  'Q',
#  'O',
#  'R',
#  'B',
#  'Q',
#  'G',
#  'F',
#  'J',
#  'N',
#  'Z',
#  'T',
#  'Y',
#  'N',
#  'P',
#  'L',
#  'C',
#  'U',
#  'G',
#  'Z',
#  'W',
#  'S',
#  'S',
#  'V',
#  'O',
#  'B',
#  'Z',
#  'L',
#  'M',
#  'R',
#  'P',
#  'T',
#  'A',
#  'Z',
#  'N',
#  'L',
#  'F',
#  'R',
#  'W',
#  'X',
#  'B',
#  'B',
#  'Z',
#  'B',
#  'Y',
#  'Z',
#  'D',
#  'W',
#  'G',
#  'K',
#  'T',
#  'C',
#  'C',
#  'H',
#  'Z',
#  'D',
#  'I',
#  'Z',
#  'M',
#  'E',
#  'S',
#  'A',
#  'T',
#  'F',
#  'D',
#  'O',
#  'H',
#  'A',
#  'W',
#  'W',
#  'Q',
#  'X',
#  'V',
#  'Q',
#  'B',
#  'O',
#  'O',
#  'J',
#  'R',
#  'I',
#  'R',
#  'R',
#  'F',
#  'L',
#  'M',
#  'Q',
#  'S',
#  'J',
#  'X',
#  'E',
#  'S',
#  'U',
#  'F',
#  'X',
#  'X',
#  'G',
#  'T',
#  'K',
#  'B',
#  'B',
#  'M',
#  'C',
#  'E',
#  'I',
#  'I',
#  'A',
#  'L',
#  'E',
#  'K',
#  'U',
#  'G',
#  'O',
#  'V',
#  'R',
#  'X',
#  'X',
#  'P',
#  'R',
#  'O',
#  'C',
#  'B',
#  'J',
#  'M',
#  'E',
#  'X',
#  'D',
#  'X',
#  'V',
#  'A',
#  'Q',
#  'L',
#  'U',
#  'G',
#  'Y',
#  'W',
#  'L',
#  'W',
#  'Z',
#  'W',
#  'O',
#  'C',
#  'Z',
#  'O',
#  'C',
#  'P',
#  'Q',
#  'S',
#  'V',
#  'F',
#  'S',
#  'B',
#  'N',
#  'L',
#  'Y',
#  'B',
#  'B',
#  'G',
#  'Q',
#  'B',
#  'H',
#  'J',
#  'D',
#  'K',
#  'M',
#  'E',
#  'O',
#  'T',
#  'Y',
#  'G',
#  'B',
#  'R',
#  'O',
#  'B',
#  'R',
#  'U',
#  'S',
#  'F',
#  'J',
#  'Z',
#  'I',
#  'T',
#  'K',
#  'W',
#  'S',
#  'B',
#  'M',
#  'G',
#  'J',
#  'M',
#  'X',
#  'S',
#  'Z',
#  'U',
#  'Q',
#  'F',
#  'J',
#  'L',
#  'G',
#  'R',
#  'W',
#  'L',
#  'E',
#  'G',
#  'P',
#  'N',
#  'K',
#  'P',
#  'D',
#  'W',
#  'A',
#  'W',
#  'R',
#  'B',
#  'S',
#  'Y',
#  'L',
#  'M',
#  'Q',
#  'E',
#  'M',
#  'M',
#  'X',
#  'O',
#  'R',
#  'Z',
#  'L',
#  'O',
#  'T',
#  'J',
#  'G',
#  'P',
#  'W',
#  'P',
#  'X',
#  'I',
#  'C',
#  'C',
#  'V',
#  'J',
#  'F',
#  'B',
#  'S',
#  'S',
#  'O',
#  'R',
#  'L',
#  'L',
#  'K',
#  'H',
#  'R',
#  'F',
#  'H',
#  'Q',
#  'K',
#  'Z',
#  'K',
#  'Y',
#  'N',
#  'B',
#  'C',
#  'S',
#  'L',
#  'K',
#  'Z',
#  'E',
#  'U',
#  'F',
#  'P',
#  'Q',
#  'C',
#  'U',
#  'O',
#  'Y',
#  'V',
#  'P',
#  'L',
#  'M',
#  'O',
#  'O',
#  'I',
#  'U',
#  'L',
#  'Y',
#  'I',
#  'I',
#  'K',
#  ...]
